# %% [markdown]
# # Plotting and Visualization

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# %matplotlib notebook

# %% [markdown]
# ## A Brief matplotlib API Primer

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
data = np.arange(10)
data
plt.plot(data)

# %% [markdown]
# ### Figures and Subplots

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %% [markdown]
# fig = plt.figure()
# ax1 = fig.add_subplot(2, 2, 1)
# ax2 = fig.add_subplot(2, 2, 2)
# ax3 = fig.add_subplot(2, 2, 3)

# %%
a = np.random.randn(50)
print(a)
print(a.cumsum())
plt.plot(a.cumsum(), 'k--')
# Out:
# [-0.2047  0.4789 -0.5194 -0.5557  1.9658  1.3934  0.0929  0.2817  0.769
#   1.2464  1.0072 -1.2962  0.275   0.2289  1.3529  0.8864 -2.0016 -0.3718
#   1.669  -0.4386 -0.5397  0.477   3.2489 -1.0212 -0.5771  0.1241  0.3026
#   0.5238  0.0009  1.3438 -0.7135 -0.8312 -2.3702 -1.8608 -0.8608  0.5601
#  -1.2659  0.1198 -1.0635  0.3329 -2.3594 -0.1995 -1.542  -0.9707 -1.307
#   0.2863  0.378  -0.7539  0.3313  1.3497]
# [-0.2047  0.2742 -0.2452 -0.8009  1.1648  2.5583  2.6512  2.9329  3.7019
#   4.9484  5.9556  4.6593  4.9343  5.1632  6.5162  7.4026  5.4009  5.0291
#   6.6981  6.2596  5.7198  6.1968  9.4457  8.4245  7.8474  7.9716  8.2742
#   8.7979  8.7989 10.1427  9.4291  8.598   6.2278  4.367   3.5062  4.0664
#   2.8005  2.9203  1.8568  2.1896 -0.1698 -0.3693 -1.9113 -2.882  -4.1891
#  -3.9027 -3.5247 -4.2786 -3.9473 -2.5976]

# %%
x = np.random.randn(100)
_ = ax1.hist(x, bins=20, color='purple', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig

# %%
fig

# %%
plt.close('all')

# %%
fig, axes = plt.subplots(2, 3)
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f508c607710>,
# ...
#       dtype=object)

# %% [markdown]
# #### Adjusting the spacing around subplots

# %% [markdown]
# subplots_adjust(left=None, bottom=None, right=None, top=None,
#                 wspace=None, hspace=None)

# %% [markdown]
# fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
# for i in range(2):
#     for j in range(2):
#         axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
# plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0.1, hspace=0.1)

# %% [markdown]
# ### Colors, Markers, and Line Styles

# %% [markdown]
# # ax.plot(x, y, 'g--')

# %% [markdown]
# ax.plot(x, y, linestyle='--', color='g')

# %%
plt.figure()

# %%
from numpy.random import randn
plt.plot(randn(30).cumsum(), 'k+--')

# %% [markdown]
# plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
plt.close('all')

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %% [markdown]
# ### Ticks, Labels, and Legends

# %% [markdown]
# #### Setting the title, axis labels, ticks, and ticklabels

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %%
ticks = ax.set_xticks([0,100,200,300,400, 500, 600, 700,800,900, 1000])
labels = ax.set_xticklabels(['ZERO', 'HUNDRED', 'TWO HUNDRED', 'THREE HUNDRED', 'FOUR HUNDRED', 'FIVE HUNDRED','SIX HUNDRED','SEVEN HUNDRED','EIGHT HUNDRED','NINE HUNDRED','TEN HUNDRED'], rotation=30, fontsize='small')

# %%
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Iteration No.')
# Out:
# Text(0.5, 3.200000000000003, 'Iteration No.')

# %%
fig

# %% [markdown]
# props = {
#     'title': 'My first matplotlib plot',
#     'xlabel': 'Stages'
# }
# ax.set(**props)

# %% [markdown]
# #### Adding legends

# %%
from numpy.random import randn
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')

# %%
ax.legend(loc='best')

# %%
fig

# %% [markdown]
# ### Annotations and Drawing on a Subplot

# %% [markdown]
# ax.text(x, y, 'Hello world!',
#         family='monospace', fontsize=10)

# %%
from datetime import datetime

fig = plt.figure()

data = pd.read_csv('/content/drive/MyDrive/stock_px_2.csv', index_col=0, parse_dates=True)
data
# Out:
#               AAPL   MSFT    XOM      SPX
# 2003-01-02    7.40  21.11  29.22   909.03
# 2003-01-03    7.45  21.14  29.24   908.59
# 2003-01-06    7.45  21.52  29.96   929.01
# 2003-01-07    7.43  21.93  28.95   922.93
# 2003-01-08    7.28  21.31  28.83   909.93
# ...            ...    ...    ...      ...
# 2011-10-10  388.81  26.94  76.28  1194.89
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58
#
# [2214 rows x 4 columns]

# %%
ax = fig.add_subplot(1, 1, 1)

spx = data['SPX']

spx.plot(ax=ax, style='k--')
fig

# %%
crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='bottom')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 financial crisis')

# %%
fig

# %%
fig.clf()
fig

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ax.set_title('Important dates in the 2008–2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008–2009 financial crisis')

# %% [markdown]
# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)
#
# rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
# circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
# pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
#                    color='g', alpha=0.5)
#
# ax.add_patch(rect)
# ax.add_patch(circ)
# ax.add_patch(pgon)

# %%
fig = plt.figure(figsize=(12, 6)); ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.8)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],color='g', alpha=0.8)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %% [markdown]
# ### Saving Plots to File

# %% [markdown]
# ## plt.savefig('figpath.svg')

# %% [markdown]
# plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# from io import BytesIO
# buffer = BytesIO()
# plt.savefig(buffer)
# plot_data = buffer.getvalue()

# %% [markdown]
# ### matplotlib Configuration

# %% [markdown]
# *plt*.rc('figure', figsize=(10, 10))

# %% [markdown]
# font_options = {'family' : 'monospace',
#                 'weight' : 'bold',
#                 'size'   : 'small'}
# plt.rc('font', **font_options)

# %% [markdown]
# ## Plotting with pandas and seaborn

# %% [markdown]
# ### Line Plots

# %%
plt.close('all')

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df[['A','B']].plot()

# %% [markdown]
# ### Bar Plots

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='g', alpha=0.7)
data.plot.barh(ax=axes[1], color='b', alpha=0.7)

# %%
np.random.seed(12348)

# %%
df = pd.DataFrame(np.random.rand(6, 4),index=['one', 'two', 'three', 'four', 'five', 'six'], columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
df.plot.bar()

# %%
plt.figure()

# %%
df.plot.barh(stacked=True, alpha=0.5)

# %%
df.plot.bar(stacked=True, alpha=0.5)

# %%
plt.close('all')

# %%
tips = pd.read_csv('/content/drive/MyDrive/pydata-book-2nd-edition.zip (Unzipped Files)/pydata-book-2nd-edition/examples/tips.csv')
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
party_counts = pd.crosstab(tips['day'], tips['size'])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts
# Not many 1- and 6-person parties
party_counts = party_counts.loc[:, 2:5]
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
party_counts.plot.bar()

# %%
party_pcts = party_counts.div(party_counts.sum(1), axis=0)
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
# Normalize to sum to 1
party_pcts = party_counts.div(party_counts.sum(1), axis=0)
party_pcts
party_counts.plot.bar()
party_pcts.plot.bar()

# %%
plt.close('all')

# %%
import seaborn as sns
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips.head()
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')

# %%
plt.close('all')

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h')

# %%
plt.close('all')

# %%
sns.set(style="whitegrid")

# %% [markdown]
# ### Histograms and Density Plots

# %%
plt.figure()

# %%
tips['tip_pct'].plot.hist(bins=50)
plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %%
tips['tip_pct'].plot.hist(bins=50)
plt.savefig('/content/drive/MyDrive/pydata-book-2nd-edition.zip (Unzipped Files)/pydata-book-2nd-edition/datasets/figpath.png', dpi=400, bbox_inches='tight')

# %%
plt.figure()

# %%
tips['tip_pct'].plot.density()

# %%
plt.figure()

# %%
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values, bins=100, color='k')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Scatter or Point Plots

# %%
macro = pd.read_csv('/content/drive/MyDrive/pydata-book-2nd-edition.zip (Unzipped Files)/pydata-book-2nd-edition/examples/macrodata.csv')
macro
# Out:
#        year  quarter    realgdp  realcons  ...  unemp      pop  infl  realint
# 0    1959.0      1.0   2710.349    1707.4  ...    5.8  177.146  0.00     0.00
# 1    1959.0      2.0   2778.801    1733.7  ...    5.1  177.830  2.34     0.74
# 2    1959.0      3.0   2775.488    1751.8  ...    5.3  178.657  2.74     1.09
# 3    1959.0      4.0   2785.204    1753.7  ...    5.6  179.386  0.27     4.06
# 4    1960.0      1.0   2847.699    1770.5  ...    5.2  180.007  2.31     1.19
# ..      ...      ...        ...       ...  ...    ...      ...   ...      ...
# 198  2008.0      3.0  13324.600    9267.7  ...    6.0  305.270 -3.16     4.33
# 199  2008.0      4.0  13141.920    9195.3  ...    6.9  305.952 -8.79     8.91
# 200  2009.0      1.0  12925.410    9209.2  ...    8.1  306.547  0.94    -0.71
# 201  2009.0      2.0  12901.504    9189.0  ...    9.2  307.226  3.37    -3.19
# 202  2009.0      3.0  12990.341    9256.0  ...    9.6  308.013  3.56    -3.44
#
# [203 rows x 14 columns]

# %%
macro = pd.read_csv('/content/drive/MyDrive/pydata-book-2nd-edition.zip (Unzipped Files)/pydata-book-2nd-edition/examples/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna()
trans_data.tail()
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
plt.figure()

# %%
sns.regplot('m1', 'unemp', data=trans_data)
plt.title('Changes in log %s versus log %s' % ('m1', 'unemp'))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Changes in log m1 versus log unemp')

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2})

# %% [markdown]
# ### Facet Grids and Categorical Data

# %%
sns.factorplot(x='day', y='tip_pct', hue='time', col='smoker',
               kind='bar', data=tips[tips.tip_pct < 0.5])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day', y='tip_pct', row='time',
               col='smoker',
               kind='bar', data=tips[tips.tip_pct < 0.2])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='tip_pct', y='day', kind='box',
               data=tips[tips.tip_pct < 0.5])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ## Other Python Visualization Tools

# %%
pd.options.display.max_rows = PREVIOUS_MAX_ROWS

# %% [markdown]
# ## Conclusion

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
